# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install --upgrade pip

# !pip install \
numpy==1.26.4 \
scipy==1.13.1 \
pandas==2.2.2 \
scikit-learn==1.5.2 \
pyarrow==17.0.0
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 23.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 91.5 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 48.8 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.9/12.9 MB 80.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.9/39.9 MB 49.1 MB/s  0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.16.3
#     Uninstalling scipy-1.16.3:
#       Successfully uninstalled scipy-1.16.3
#   Attempting uninstall: pyarrow
#     Found existing installation: pyarrow 18.1.0
#     Uninstalling pyarrow-18.1.0:
# ...

# %%
# !git clone --branch tuanphat --single-branch https://github.com/internvietridao/MockProject_062026_NhomAI.git

# %cd /content/MockProject_062026_NhomAI/Training

# !pip install -r requirements_ver1.txt --no-deps
# Out:
# Cloning into 'MockProject_062026_NhomAI'...
# remote: Enumerating objects: 11599, done.
# remote: Counting objects: 100% (79/79), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 11599 (delta 50), reused 45 (delta 27), pack-reused 11520 (from 4)
# Receiving objects: 100% (11599/11599), 174.50 MiB | 22.69 MiB/s, done.
# Resolving deltas: 100% (6926/6926), done.
# Updating files: 100% (11419/11419), done.
# /content/MockProject_062026_NhomAI/Training
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 20.1 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 MB 58.8 MB/s  0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 76.5 MB/s  0:00:00
# ...

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.environ["TRANSFORMERS_VERBOSITY"] = "error"
os.environ["HF_HUB_DISABLE_XET"] = "1"

# %%
from ragas import evaluate
from ragas.metrics import faithfulness, answer_relevancy, context_precision, context_recall
print("ragas import OK")
# Out:
# ragas import OK

# %%
import pandas as pd

RESULTS_CSV = "/content/drive/MyDrive/medquad_eval/ragas_scores.csv"  # đúng path bạn đang dùng

df = pd.read_csv(RESULTS_CSV)
print("Trước khi dedup:", len(df))
df = df.drop_duplicates(subset=["user_input"], keep="last")  # giữ lần chấm gần nhất
print("Sau khi dedup:", len(df))
df.to_csv(RESULTS_CSV, index=False)
# Out:
# Trước khi dedup: 160
# Sau khi dedup: 160

# %%
import os
os.environ["MEDQUAD_JUDGE_API_KEY"] = "gsk..." # API key here
os.environ["MEDQUAD_JUDGE_API_BASE"] = "https://api.groq.com/openai/v1"
os.environ["MEDQUAD_JUDGE_API_MODEL"] = "llama-3.3-70b-versatile"

# Reload lại src.config VÀ pipeline.evaluate để đọc đúng giá trị mới
import importlib
import src.config
importlib.reload(src.config)

from pipeline import evaluate
importlib.reload(evaluate)

evaluate.main()
# Out:
# Kết quả đánh giá sẽ được lưu (append theo batch) vào: /content/drive/MyDrive/medquad_eval/ragas_scores.csv
# Kết quả đánh giá sẽ được lưu (append theo batch) vào: /content/drive/MyDrive/medquad_eval/ragas_scores.csv
# Đang đọc CSV dự đoán (đã sinh sẵn từ bước train, gồm ROUGE/BLEU)...
# Số mẫu: 5495
# Đang khởi tạo model giám khảo (tách biệt model vừa train)...
# Gọi model giám khảo qua API: llama-3.3-70b-versatile (https://api.groq.com/openai/v1)
# /content/MockProject_062026_NhomAI/Training/pipeline/evaluate.py:156: LangChainBetaWarning: Introduced in 0.2.24. API subject to change.
#   rate_limiter = InMemoryRateLimiter(
# Đang load embedding model (cho Answer Relevance)...
# ...
